# %%
import skrf as rf
from skrf.calibration import OnePort
#%matplotlib inline
import matplotlib.pyplot as plt
from pylab import *
rf.stylely()

#ideals = rf.read_all('data/ideals/')
#measured = rf.read_all('data/measured/')
#duts = rf.read_all('data/measured/')
ideals = rf.read_all('data/ideals/KirkbySN0092/')
measured = rf.read_all('data/measured/SVA/KirkbySN0092/')
duts = rf.read_all('data/measured/SVA/KirkbySN0092/')

offsetA = measured['KirkbyOpen'] - measured['KirkbyShort']
offset = measured['KirkbyOpen']
offset1 = ideals['male-short-0092'] / ideals['male-open-0092']

## create a Calibration instance
cal = rf.OnePort(
    ideals = [ideals[k] for k in ['male-short-0092','male-open-0092','male-load-0092']],
    measured = [measured[k] for k in ['SDRKitsShort','SDRKitsOpen','SDRKitsLoad']],
    #measured = [measured[k] for k in ['KirkbyShort','KirkbyOpen','KirkbyLoad']],
    )

caled_duts = [cal.apply_cal(dut) for dut in measured.values()]
#measured['KirkbyShort'].plot_s_db()
#measured['KirkbyOpen'].plot_s_db()
measured['SDRKitsShort'].plot_s_db()
#measured['SDRKitsOpen'].plot_s_db()
#caled_duts[0].plot_s_db()
#caled_duts[1].plot_s_db()
(measured['KirkbyOpen'] - offsetA).plot_s_db()
(measured['KirkbyOpen']).plot_s_db()
#(caled_duts[3] - offset).plot_s_db()
#(caled_duts[4]).plot_s_db()
#ideals['attenuator-0092-limited'].plot_s_db()
#offset.plot_s_db()
#offset.plot_s_deg()
#(measured['KirkbyShort'] / measured['KirkbyOpen']).plot_s_deg()
#(measured['KirkbyShort']).plot_s_deg()
#(measured['KirkbyOpen']).plot_s_deg()
# Out:
# Warning: Frequency information doesn't match on ideals[0], attempting to interpolate the ideal[0] Network ..
# Success
# Warning: Frequency information doesn't match on ideals[1], attempting to interpolate the ideal[1] Network ..
# Success
# Warning: Frequency information doesn't match on ideals[2], attempting to interpolate the ideal[2] Network ..
# Success
# C:\ProgramData\Anaconda3\lib\site-packages\skrf\calibration\calibration.py:1051: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   abcTmp, residualsTmp = npy.linalg.lstsq(Q,m)[0:2]

# %%
import skrf as rf
from skrf.calibration import OnePort
# %matplotlib inline
from pylab import *
rf.stylely()

ideals = rf.read_all('data/ideals/KirkbySN0092/')
measured = rf.read_all('data/measured/SVA/KirkbySN0092/')
duts = rf.read_all('data/measured/SVA/KirkbySN0092/')

## create a Calibration instance
cal = rf.OnePort(
    ideals = [ideals[k] for k in ['fake-male-short-0092','male-open-0092','male-load-0092']],
    #measured = [measured[k] for k in ['SDRKitsShort','SDRKitsOpen','SDRKitsLoad']],
    measured = [measured[k] for k in ['KirkbyShortOpen180','KirkbyOpen','KirkbyLoad']],
    )

caled_duts = [cal.apply_cal(dut) for dut in duts.values()]

#measured['KirkbyShort'].plot_s_db()
#measured['KirkbyOpen'].plot_s_db()
#measured['KirkbyShortOpen180'].plot_s_db()

caled_duts[0].plot_s_db()
#caled_duts[1].plot_s_db()
#caled_duts[2].plot_s_db()
#caled_duts[3].plot_s_db()
# Out:
# Warning: Frequency information doesn't match on ideals[0], attempting to interpolate the ideal[0] Network ..
# Success
# Warning: Frequency information doesn't match on ideals[1], attempting to interpolate the ideal[1] Network ..
# Success
# Warning: Frequency information doesn't match on ideals[2], attempting to interpolate the ideal[2] Network ..
# Success
# C:\ProgramData\Anaconda3\lib\site-packages\skrf\calibration\calibration.py:1051: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   abcTmp, residualsTmp = npy.linalg.lstsq(Q,m)[0:2]

# %%
import skrf as rf
from skrf.calibration import OnePort
# %matplotlib inline
from pylab import *
rf.stylely()

ideals = rf.read_all('data/ideals/')
#measured = rf.read_all('data/measured/')
#duts = rf.read_all('data/measured/')
#ideals = rf.read_all('data/ideals/KirkbySN0092/')
measured = rf.read_all('data/measured/SVA/SDRKits/')
duts = rf.read_all('data/measured/SVA/KirkbySN0092/')

## create a Calibration instance
cal = rf.OnePort(
    ideals = [ideals[k] for k in ['short','open','load']],
    measured = [measured[k] for k in ['SDRKitsShort','SDRKitsOpen','SDRKitsLoad']],
    #measured = [measured[k] for k in ['KirkbyShort','KirkbyOpen','KirkbyLoad']],
    )

caled_duts = [cal.apply_cal(dut) for dut in duts.values()]
#measured['KirkbyShort'].plot_s_db()
#measured['KirkbyOpen'].plot_s_db()
caled_duts[0].plot_s_db()
#caled_duts[1].plot_s_db()
#caled_duts[2].plot_s_db()
#caled_duts[3].plot_s_db()
#caled_duts[4].plot_s_db()
# Out:
# Warning: Frequency information doesn't match on ideals[0], attempting to interpolate the ideal[0] Network ..
# Success
# Warning: Frequency information doesn't match on ideals[1], attempting to interpolate the ideal[1] Network ..
# Success
# Warning: Frequency information doesn't match on ideals[2], attempting to interpolate the ideal[2] Network ..
# Success
# C:\ProgramData\Anaconda3\lib\site-packages\skrf\calibration\calibration.py:1051: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   abcTmp, residualsTmp = npy.linalg.lstsq(Q,m)[0:2]

# %%
import skrf as rf
from skrf.calibration import OnePort
# %matplotlib inline
from pylab import *
rf.stylely()

idealsPerfect = rf.read_all('data/ideals/')
idealsKirkby = rf.read_all('data/ideals/KirkbySN0092/')
measuredKirkby = rf.read_all('data/measured/SVA/KirkbySN0092/')
measuredSDRKits = rf.read_all('data/measured/SVA/SDRKits/')
duts = rf.read_all('data/measured/SVA/KirkbySN0092/')

## Calibrate based on Kirkby supplied data with measured data
cal_1 = rf.OnePort(
    ideals = [idealsKirkby[k] for k in ['male-short-0092','male-open-0092','male-load-0092']],
    measured = [measuredKirkby[k] for k in ['KirkbyShort','KirkbyOpen','KirkbyLoad']],
    )
## Calibrate based on Kirkby supplied data with measured data including Faked Short measurement
cal_2 = rf.OnePort(
    ideals = [idealsKirkby[k] for k in ['fake-male-short-0092','male-open-0092','male-load-0092']],
    measured = [measuredKirkby[k] for k in ['KirkbyShortOpen180','KirkbyOpen','KirkbyLoad']],
    )
## Calibrate based on Kirkby supplied data  and SDR Kits standards. This one is poor as expected as the standards are not characterised
cal_3 = rf.OnePort(
    ideals = [idealsPerfect[k] for k in ['male-short-0092','male-open-0092','male-load-0092']],
    measured = [measuredSDRKits[k] for k in ['SDRKitsShort','SDRKitsOpen','SDRKitsLoad']],
    )

caled_dutsKirkby = [cal_1.apply_cal(dut) for dut in duts.values()]
caled_dutsKirkbyFakeShort = [cal_2.apply_cal(dut) for dut in duts.values()]
#caled_dutsSDRKits = [cal_3.apply_cal(dut) for dut in duts.values()]

caled_dutsKirkby[0].plot_s_db()
caled_dutsKirkbyFakeShort[0].plot_s_db()
#caled_dutsSDRKits[0].plot_s_db()
idealsKirkby['attenuator-0092-limited'].plot_s_db()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7f38066e0995> in <module>
# ----> 1 import skrf as rf
#       2 from skrf.calibration import OnePort
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 from pylab import *
#       5 rf.stylely()
#
# ModuleNotFoundError: No module named 'skrf'
